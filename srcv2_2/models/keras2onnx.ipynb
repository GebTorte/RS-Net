# %%
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.models import load_model
import keras
import tf2onnx
import onnxruntime
#import onnx
#import keras2onnx

# %%
import numpy as np
import tensorflow as tf
import tensorflow.distribute
import keras.utils
from keras.models import Model
from keras import regularizers
from keras.metrics import Precision, Recall
from keras.initializers import GlorotNormal, HeNormal
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, Dropout, Cropping2D, Activation, BatchNormalization
from keras.optimizers import AdamW

from keras.models import Model
from keras.layers import *
import keras

from keras import backend as K

# %%
onnx_model_name = 'dummy_M2.onnx'

model = keras.saving.load_model('/home/mxh/RS-Net/models/Unet/dummy_240629081953_240704182802.keras')
onnx_model = tf2onnx.convert_keras(model, model.name)
tf2onnx.save_model(onnx_model, onnx_model_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/tf2+gpu/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:796, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     795 try:
# --> 796     mod = importlib.import_module(module)
#     797 except ModuleNotFoundError:
#
# File ~/anaconda3/envs/tf2+gpu/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# ...
