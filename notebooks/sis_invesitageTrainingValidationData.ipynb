# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
npy_img = np.load("/home/mxh/RS-Net/data/processed/train/img/barr_LC80420082013220LGN00_x_patch-83.npy")

# %%
fig, axes = plt.subplots(1,10)

for i, ax in enumerate(axes.flat):
    ax.imshow(npy_img[:,:,i])

# %%
mask_npy = np.load("/home/mxh/RS-Net/data/processed/train/mask/barr_LC80420082013220LGN00_y_patch-83.npy")

# %%
mask_npy.min()
# Out:
# 128

# %%
mask_npy.max()
# Out:
# 128

# %%
plt.imshow(mask_npy)
