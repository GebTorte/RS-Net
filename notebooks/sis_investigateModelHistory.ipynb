# %%
import matplotlib.pyplot as plt
from matplotlib import interactive
import numpy as np

# conda install ipympl
#options: widget, notebook, 
# %matplotlib widget

# %%
project_path = "/home/mxh/RS-Net/"
modelID = "binary_M1_240605215803"# "240530184700-CV1of2" #"Unet-v2-binary_240526173722"# "240524133651-CV1of2"

# %%
hist =  np.load(f"{project_path}reports/Unet/histories/{modelID}_history.npy", allow_pickle=True).item()

# %%
hist.keys()
# Out:
# dict_keys(['loss', 'binary_crossentropy', 'jaccard_coef_loss', 'jaccard_coef', 'jaccard_coef_thresholded', 'accuracy', 'val_loss', 'val_binary_crossentropy', 'val_jaccard_coef_loss', 'val_jaccard_coef', 'val_jaccard_coef_thresholded', 'val_accuracy'])

# %%
fig, ax = plt.subplots()

ax.plot(hist["val_accuracy"], color="blue")
ax.set_xlabel("Epochen")
ax.set_ylabel("Validierungs Acc.", color="blue")
ax.set_xticks([0, 10 , 20, 30, 35, 41])
ax.tick_params(axis = "y", labelcolor="blue")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()

ax.set_xlabel("Epochen")
ax.set_xticks([0, 10 , 20, 30, 35, 41])

ax.plot(hist["loss"], color="blue")
ax.set_ylabel("Trainings Loss", color="blue")
ax.set_yticks([0.05, 0.10, 0.15, 0.20, 0.25, 0.30])
ax.tick_params(axis="y", labelcolor="blue")

ax2 = ax.twinx()
ax2.plot(hist["val_loss"], color="red")
ax2.set_ylabel("Validierungs Loss", color="red")
ax2.set_yticks([0,20,40,60,80,100,120])
ax2.tick_params(axis="y", labelcolor="red")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## confusion matrix

# %%
#Predict
y_prediction = model.predict(x_test)
y_prediction = np.argmax(y_prediction, axis = 1)
y_test=np.argmax(y_test, axis=1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_test, y_prediction , normalize='pred')
print(result)
