# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
project_path = "/home/mxh/RS-Net/"
modelID = "240524133651-CV1of2"

# %%
hist =  np.load(f"{project_path}reports/Unet/histories/{modelID}_history.npy", allow_pickle=True).item()

# %%
hist.keys()
# Out:
# dict_keys(['loss', 'sparse_categorical_crossentropy', 'sparse_categorical_accuracy', 'sparse_top_k_categorical_accuracy', 'val_loss', 'val_sparse_categorical_crossentropy', 'val_sparse_categorical_accuracy', 'val_sparse_top_k_categorical_accuracy', 'lr'])

# %%
plt.plot(hist["lr"])

# %%
plt.plot(hist["loss"])
plt.plot(hist["val_loss"])
